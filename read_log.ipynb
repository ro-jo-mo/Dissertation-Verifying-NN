# %%
import pickle
def read(path):
    with open(path,"rb") as f:
        abc = pickle.load(f)
        for _,var in abc.items():
            total = len(var["unsafe-pgd"]) + len(var["unknown"]) + len(var["safe"]) + len(var["safe-incomplete"])
            verified = len(var["safe"]) + len(var["safe-incomplete"])
            print(f"Verified Percentage: {100 * verified / total:.1f}")
            for a,b in var.items():
                print(f"{a} : {b}")
            break

# %%
path = "/home/rob/code/Project/alpha-beta-CROWN/complete_verifier/base_epsilon_15.pth.pkl"
read(path)
# Out:
# Verified Percentage: 51.2
# unsafe-pgd : [0, 3, 7, 9, 10, 13, 16, 17, 25, 28, 31, 35, 38, 39, 40, 41, 42, 44, 47, 48, 52, 53, 61, 62, 65, 66, 68, 69, 70, 71, 72, 74, 80]
# safe-incomplete : [1, 12, 14, 18, 20, 26, 27, 32, 37, 43, 51, 54, 59, 63, 75, 76, 77, 79]
# safe : [2, 5, 6, 8, 15, 19, 21, 22, 23, 24, 29, 30, 33, 45, 49, 50, 55, 56, 57, 64, 67, 73, 78, 81]
# unknown : [4, 11, 34, 36, 46, 58, 60]

# %%
path = "/home/rob/code/Project/alpha-beta-CROWN/complete_verifier/base_epsilon_0.020.pth.pkl"
read(path)
# Out:
# Verified Percentage: 27.0
# unknown : [0, 1, 3, 5, 8, 13, 15, 17, 18, 19, 22, 30, 33, 34, 35, 37, 38, 39, 43, 44, 45, 46, 47, 66, 68, 69, 70, 72, 73, 76, 79, 82, 88, 89, 90, 96, 98]
# safe-incomplete : [2, 6, 9, 10, 20, 24, 26, 27, 53, 60, 67, 77, 86, 91]
# unsafe-pgd : [4, 7, 11, 12, 14, 16, 23, 25, 28, 29, 32, 36, 41, 42, 48, 50, 51, 52, 54, 58, 61, 64, 65, 74, 75, 78, 80, 81, 83, 84, 85, 87, 92, 93, 94, 99]
# safe : [21, 31, 40, 49, 55, 56, 57, 59, 62, 63, 71, 95, 97]

# %%
path = "/home/rob/code/Project/alpha-beta-CROWN/complete_verifier/base_epsilon_0.039.pth.pkl"
read(path)
# Out:
# Verified Percentage: 40.0
# unsafe-pgd : [0, 5, 11, 12, 14, 16, 23, 25, 28, 29, 32, 33, 41, 42, 48, 51, 52, 54, 55, 58, 61, 65, 74, 80, 81, 83, 84, 85, 87, 92, 93, 94, 98, 99]
# safe : [1, 3, 15, 17, 21, 30, 34, 37, 43, 45, 47, 50, 56, 57, 66, 78, 88, 96]
# safe-incomplete : [2, 6, 9, 10, 20, 24, 26, 27, 31, 40, 49, 53, 59, 60, 62, 63, 67, 71, 77, 86, 91, 95]
# unknown : [4, 7, 8, 13, 18, 19, 22, 35, 36, 38, 39, 44, 46, 64, 68, 69, 70, 72, 73, 75, 76, 79, 82, 89, 90, 97]

# %%
path = "/home/rob/code/Project/alpha-beta-CROWN/complete_verifier/base_epsilon_0.059.pth.pkl"
read(path)
# Out:
# Verified Percentage: 49.0
# unknown : [0, 25, 33, 36, 38, 68, 76, 79, 89, 99]
# safe : [1, 3, 13, 18, 19, 31, 35, 37, 39, 43, 47, 50, 57, 70, 73, 75, 88, 90, 97]
# safe-incomplete : [2, 6, 9, 10, 15, 20, 21, 24, 26, 27, 30, 34, 40, 45, 49, 53, 55, 56, 59, 60, 62, 63, 66, 67, 71, 77, 86, 91, 95, 96]
# unsafe-pgd : [4, 5, 7, 8, 11, 12, 14, 16, 17, 22, 23, 28, 29, 32, 41, 42, 44, 46, 48, 51, 52, 54, 58, 61, 64, 65, 69, 72, 74, 78, 80, 81, 82, 83, 84, 85, 87, 92, 93, 94, 98]

# %%
path = "/home/rob/code/Project/alpha-beta-CROWN/complete_verifier/base_epsilon_0.078.pth.pkl"
read(path)
# Out:
# Verified Percentage: 47.0
# unsafe-pgd : [0, 4, 5, 7, 8, 11, 12, 14, 16, 17, 22, 23, 28, 29, 32, 37, 41, 42, 44, 46, 47, 48, 51, 52, 54, 58, 61, 64, 65, 68, 69, 72, 74, 78, 80, 81, 82, 83, 84, 85, 87, 89, 92, 93, 94, 97, 98]
# safe-incomplete : [1, 2, 6, 9, 10, 15, 20, 24, 25, 26, 27, 30, 31, 34, 39, 40, 45, 49, 53, 56, 57, 59, 60, 62, 63, 67, 71, 73, 77, 86, 88, 91, 95, 96, 99]
# safe : [3, 13, 21, 33, 35, 38, 43, 55, 66, 70, 79, 90]
# unknown : [18, 19, 36, 50, 75, 76]
