# %%
import idx2numpy
import cv2
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import os
np.set_printoptions(threshold=np.inf)

# %%
PATH = Path("dataset") / "GTSRB" / "Training"
_N = 32
def convert_dataset():
    total = []
    labels = []
    for path,_,files in os.walk(PATH):        
        for file in files:
            if file.endswith(".png"):
                label = int(os.path.basename(path))
                file_path = Path(path) / file
                img = cv2.imread(file_path)
                img = cv2.resize(img,(32,32))
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY).astype(np.float32)
                img /= 255.0
                total  += [img]
                labels += [label]
    return total, labels
images, labels = convert_dataset()

# %%
images = np.array(images)
labels = np.array(labels)

# %%
print(labels.shape)
print(images.shape)
# Out:
# (39209,)
# (39209, 32, 32)

# %%
plt.imshow(img,cmap="gray")

# %%
def func():
    # Reading
    path = Path("examples") / "mnist-robustness" / "t2-images.idx"
    ndarr = idx2numpy.convert_from_file(str(path))
    print(ndarr.shape)
    plt.imshow(ndarr[0],cmap="gray")

func()
# Out:
# (2, 28, 28)
